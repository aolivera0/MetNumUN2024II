# %% [markdown]
# <a href="https://colab.research.google.com/github/aolivera0/MetNumUN2024II/blob/main/LabATQ/LAB_ATQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB ATQ
# #### Métodos numéricos.
# #### Angel H Olivera Pinzón

# %% [markdown]
# Link del archivo en Quantiacs:
# https://u2926969-s18015314.n1.s.quantiacs.com/lab/tree/strategy.ipynb

# %% [markdown]
# # 1. Cambio del modelo de Machine Learning
#
# En este caso utilicé el modelo de [Gradient Boosting Regresor](https://scikit-learn.org/1.6/modules/generated/sklearn.ensemble.GradientBoostingRegressor.html) que aunque es una variante de la regresión lineal, en la teoría resulta especialmente efectivo para el análisis de datos financieros.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2. Cambio del mercado
# Cambié la data al mercado de S&P500 y entrené el modelo con las 20 empresas más importantes del mismo. Escogí estas empresas porque juntas representan casi el 50% del indicador. Es decir, resulta ser una muestra significativa.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 3. Variables
# Solo agregué la variable de si el activo es liquido o no, las demás variables son las del ejemplo inicial.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4. Targets
# Se agregó la opción de vender cuando el precio de la acción baja
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 5. Solo activos liquidos
# Se agrego la variable de liquidez como se mencionó anteriormente
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #6.1 Resultados compra y venta
#
# Para el analisis corto de los 5 años se obtienen muy buenos resultados
#
# ![image.png](data:image/png;base64,...)
#
# Sin embargo, al correr el backtesting se presenta un error y el modelo por alguna razón solo va perdiendo y perdiendo obteniendo un sharp ratio de -1.76
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #6.2 Resultados solo compra
# ![image.png](data:image/png;base64,...)
#
# Análisis rápido
#
# ![image.png](data:image/png;base64,...)
#
# Backtesting
#
# ![image.png](data:image/png;base64,...)
#
# Sharp ratio: 0.32

# %% [markdown]
# #6.3 Solo venta
# ![image.png](data:image/png;base64,...)
#
# Análisis rápido
#
# ![image.png](data:image/png;base64,...)
#
# Backtesting
#
# ![image.png](data:image/png;base64,...)
#
# Sharp ratio: -1.23
